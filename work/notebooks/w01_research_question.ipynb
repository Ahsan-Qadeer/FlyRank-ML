# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Ahsan-Qadeer/FlyRank-ML/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# # 1. My lane (or freestyle) and why
#
# ##Lane chosen: Refresh / Content Scoring Opportunity
#
# I have chosen this lane since it focuses on building ranking and recommendation systems. It matches my interest in ML, ranking algorithms, and practical AI. This lane will help me solve real business issues instead of only focusing on data anallysis.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# Question: Which pages should be prioritized to bbe reviewed based on search and engagement signals?
#
# Decision: Determine the pages to be reviewed first
#
# Action: SEO specialist reviews the highest ranked pages before low priority pages.
#
# Cost of wrong recc: Review time wasted on already well performing pages, and in turn cause declining pages to lose even more traffic.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# The dataset has 30000 content pages with 44 features that can be observed
#
# Random Forest achieved a Precision@50 of 0.74, compared to 0.24 for the hand written baseline rule. This means the model identified around 37 of the top 50 review candidatees, compared to 12/50 for the baseline, confirming that learned ranking improved prioritization
#
# These results suggest that the data has enough signnal to build better review ranking system.

# %%
import json
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
print("Rows:", len(df))
print("Columns:", len(df.columns))

res = json.load(open("outputs/model_results.json"))
print("Baseline Precision@50:", res["baseline"]["baseline_precision_at_50"])
print("Random Forest Precision@50:", res["models"]["random_forest"]["precision_at_50"])

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# The project proves decision support through ranking pages for review using search and engagement signals. It can find patterns and then prioritize pages, however it cant prove that refreshing a page will iimprove performance or predict the ranking decisiions of Google. Prior to taking action, human review is still essential

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
